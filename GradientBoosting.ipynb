# %%
from Load_to_DataFrame import *

# %%
# df = load_all()

# %%
from sklearn import datasets

# %%
diabetes = datasets.load_diabetes()

# %%
X = diabetes.data

# %%
y = diabetes.target

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()

# %%
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = gbr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 49.13833466906022

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 3754.3857338826188

# %%
r2_score(y_test, y_pred)
# Out:
# 0.3642264278270503

# %%
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.005, 0.002],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3],
    'criterion': ['friedman_mse'],
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gbr_cv = GridSearchCV(gbr, param_grid, cv=3, n_jobs=4, scoring='neg_mean_squared_error')

# %%
gbr_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(), n_jobs=4,
#              param_grid={'criterion': ['friedman_mse'],
#                          'learning_rate': [0.01, 0.005, 0.002],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [100, 500, 1000]},
#              scoring='neg_mean_squared_error')

# %%
y_pred = gbr_cv.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 48.39938143531645

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 3551.2157865784184

# %%
r2_score(y_test, y_pred)
# Out:
# 0.39863154555111524

# %%
gbr_cv.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.005,
#  'max_depth': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 4,
#  'n_estimators': 1000}

# %%
gbr_cv.best_score_
# Out:
# -3395.5479058627166
